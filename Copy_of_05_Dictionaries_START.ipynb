# %% [markdown]
# ##Collection Type: Dictionaries
# ###Properties as Key-Value Pairs
#
# - a **dictionary** is a **collection** (data structure that holds more than one value at a time)
# - like a list, a dictionary holds multiple values
# - unlike a list, there are no index positions
# - a dictionary stores items as **properties** (key-value pairs)
# - the **key** is the name of the property
# - keys must go in quotes
# - keys can have spaces, so they are not entirely like variables, despite having assigned values
# - the **value** is assigned to the key
# - properties go inside **{}** curly braces
# - a new empty dictionary can be declared with a pair of empty **{}**
# - properties ("props") can be added to a dictionary when it is declared, and/or props can be added later
# - props can have their values changed
# - props can be deleted from a dictionary
# - dictionaries are iterables, meaning they can be looped
# - Python dictionaries are very similar in structure to **JSON (JavaScript Object Notation)**

# %%
# 1. import the pprint module, which makes printing big
#    variables, such as lists and dictionaries, easier to read
import pprint as pp
from IPython.display import Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img_path = "/content/drive/MyDrive/_Python-Data-Sci-Oct-2024/images/2003_ford_mustang_gt.jpg"

# %%
# display the car image
Image(img_path, width=400)

# %%
# 2. Define a car dictionary. Values can be of any datatype, so
#.   include strings, numbers, boolean and even a list and child dictionary
car = {
    "make": "Ford",
    "model": "Mustang GT",
    "year": 2003,
    "for sale": True,
    "options": ["sun roof", "mag wheels", "leather seats", "spoiler", "frame decals"]
}
#

# %%
print(car)
print(car["make"])
print(car["model"])
print(car["year"])
car_options = car["options"]
print(car["options"])
print(car["options"][0])
print(car["options"][-1])
print(car["options"][-3:])
print(car_options[:3])
print(len(car_options))
car["options"].append("CD player")
print('car_options:', car_options)
# Out:
# {'make': 'Ford', 'model': 'Mustang GT', 'year': 2003, 'for sale': True, 'options': ['sun roof', 'mag wheels', 'leather seats', 'spoiler', 'frame decals']}
# Ford
# Mustang GT
# 2003
# ['sun roof', 'mag wheels', 'leather seats', 'spoiler', 'frame decals']
# sun roof
# frame decals
# ['leather seats', 'spoiler', 'frame decals']
# ['sun roof', 'mag wheels', 'leather seats']
# 5
# car_options: ['sun roof', 'mag wheels', 'leather seats', 'spoiler', 'frame decals', 'CD player']

# %%
# direct assignment of numeric variable to new variable
# new var is its own independent thing, w no reference to original
# if you change original, new var does NOT also change
# this is true of strings, as well
x = 5
y = x
x = 8
print(y) ## ???
# Out:
# 5

# %%
name = 'joe'
nombre = name
name = 'pete'
print(name)
print(nombre)
# Out:
# pete
# joe

# %%
# shallow copy of a list or dictionary:
# direct assigment of list/dictionary to new one
# does NOT result in a independent copy (deep copy)
# instead you get this weird linked reference:
# change the original, and the copy changes too
pets = ['bunny', 'cat', 'dog']
my_pets = pets
print(pets)
print(my_pets)
pets.append('hamster')
# Out:
# ['bunny', 'cat', 'dog']
# ['bunny', 'cat', 'dog']

# %%
my_pets.append('tarantula')

# %%
print(pets)
print(my_pets)
# Out:
# ['bunny', 'cat', 'dog', 'hamster', 'tarantula']
# ['bunny', 'cat', 'dog', 'hamster', 'tarantula']

# %%
print(pets)
print(my_pets)
# Out:
# ['bunny', 'cat', 'dog', 'hamster']
# ['bunny', 'cat', 'dog', 'hamster']

# %%
# direct assignment of dictionary also results in shallow copy
my_car = car
car["doors"] = 2

# %%
pp.pprint(my_car)
# Out:
# {'doors': 2,
#  'for sale': True,
#  'make': 'Ford',
#  'model': 'Mustang GT',
#  'options': ['sun roof',
#              'mag wheels',
#              'leather seats',
#              'spoiler',
#              'frame decals',
#              'CD player'],
#  'year': 2003}

# %%
# to make a deep copy, call copy() on the original when assigning to new var
cool_car = car.copy()

# %%
# assign a new property to the EXISITING car dictionary
# now, we use the equal sign, since we are no longer inside the {}
car["color"] = "red"

# %%
pp.pprint(car)
# Out:
# {'color': 'red',
#  'doors': 2,
#  'for sale': True,
#  'make': 'Ford',
#  'model': 'Mustang GT',
#  'options': ['sun roof',
#              'mag wheels',
#              'leather seats',
#              'spoiler',
#              'frame decals',
#              'CD player'],
#  'year': 2003}

# %%
cool_car["color"] = "orange"
pp.pprint(cool_car)
# Out:
# {'color': 'orange',
#  'doors': 2,
#  'for sale': True,
#  'make': 'Ford',
#  'model': 'Mustang GT',
#  'options': ['sun roof',
#              'mag wheels',
#              'leather seats',
#              'spoiler',
#              'frame decals',
#              'CD player'],
#  'year': 2003}

# %% [markdown]
# getting and setting property values -- and adding properties

# %%
# 2B. GET the color, model and the for sale status:
print(car["color"])
print(car["model"]) # Mustang GT
print(car["for sale"]) # True

# declare a new property w =
# assign miles property: 56789
car["miles"] = 56789
pp.pprint(car)

# 3 to SET a value, just set it as if it
# were a new property.. Increase "miles" value:
car["miles"] = 57890
pp.pprint(car)

# 4. to ADD a key, just declare it and set its value.
# Make a "doors" property
car["doors"] = 2

# values can be any data type
car["owner"] = {
    "first_name": "Brian",
    "last_name": "McClain",
    "zip_code": 11374,
    "address": {
        "city": "Rego Park",
        "state": "NY",
    }
}

# change zip code to 10011
# wrong targeting
# correct targeting

# add an option "Bluetooth" to the options list
# Out:
# red
# Mustang GT
# True
# {'color': 'red',
#  'doors': 2,
#  'for sale': True,
#  'make': 'Ford',
#  'miles': 56789,
#  'model': 'Mustang GT',
#  'options': ['sun roof',
#              'mag wheels',
#              'leather seats',
#              'spoiler',
#              'frame decals',
#              'CD player'],
#  'owner': {'first_name': 'Brian', 'last_name': 'McClain', 'zip_code': 10015},
#  'year': 2003}
# {'color': 'red',
#  'doors': 2,
#  'for sale': True,
#  'make': 'Ford',
#  'miles': 57890,
#  'model': 'Mustang GT',
#  'options': ['sun roof',
#              'mag wheels',
#              'leather seats',
#              'spoiler',
#              'frame decals',
#              'CD player'],
#  'owner': {'first_name': 'Brian', 'last_name': 'McClain', 'zip_code': 10015},
#  'year': 2003}

# %%
pp.pprint(car)
# Out:
# {'color': 'red',
#  'doors': 2,
#  'for sale': True,
#  'make': 'Ford',
#  'miles': 57890,
#  'model': 'Mustang GT',
#  'options': ['sun roof',
#              'mag wheels',
#              'leather seats',
#              'spoiler',
#              'frame decals',
#              'CD player'],
#  'owner': {'address': {'city': 'Rego Park', 'state': 'NY'},
#            'first_name': 'Brian',
#            'last_name': 'McClain',
#            'zip_code': 11374},
#  'year': 2003}

# %%
# change the owner's zip code:
car["zip_code"] = 10015

# %%
# drill allll the way in to change state to "New York"
car["owner"]["address"]["state"] = "New York"

# %%
pp.pprint(car)
# Out:
# {'color': 'red',
#  'doors': 2,
#  'for sale': True,
#  'make': 'Ford',
#  'miles': 57890,
#  'model': 'Mustang GT',
#  'options': ['sun roof',
#              'mag wheels',
#              'leather seats',
#              'spoiler',
#              'frame decals',
#              'CD player'],
#  'owner': {'address': {'city': 'Rego Park', 'state': 'New York'},
#            'first_name': 'Brian',
#            'last_name': 'McClain',
#            'zip_code': 11374},
#  'year': 2003}

# %%
# change Bluetooth to Blueteeth

# %%
# delete Blueteeth -- no more blue anything
# this means popping the last thing:

# %% [markdown]
# deleting properties and changing key names
# - **del** keyword is for deleting properties
# - you cannot directly change a key name, BUT you can copy an old key to a new key

# %%
# delete the accidentally added zip_code property which should only be in the owner dictionary
del car["zip_code"]

# %%
# now change the zip code correctly, w the proper targeting:
car["owner"]["zip_code"] = 10015

# %%
pp.pprint(car)
# Out:
# {'color': 'red',
#  'doors': 2,
#  'for sale': True,
#  'make': 'Ford',
#  'miles': 57890,
#  'model': 'Mustang GT',
#  'options': ['sun roof',
#              'mag wheels',
#              'leather seats',
#              'spoiler',
#              'frame decals',
#              'CD player'],
#  'owner': {'first_name': 'Brian', 'last_name': 'McClain', 'zip_code': 10015},
#  'year': 2003}

# %%
# change "miles" to "odometer"

# 5. declare a new "odometer" property.
# Set it equal to the existing "miles" prop:
car["odometer"] = car["miles"]

# 6. delete the old key-value pair, "miles", since it is redundant:
del car["miles"]
pp.pprint(car)
# Out:
# {'color': 'red',
#  'doors': 2,
#  'for sale': True,
#  'make': 'Ford',
#  'model': 'Mustang GT',
#  'odometer': 57890,
#  'options': ['sun roof',
#              'mag wheels',
#              'leather seats',
#              'spoiler',
#              'frame decals',
#              'CD player'],
#  'owner': {'address': {'city': 'Rego Park', 'state': 'New York'},
#            'first_name': 'Brian',
#            'last_name': 'McClain',
#            'zip_code': 11374},
#  'year': 2003}

# %%
# another way to delete a key-value pair is to pop it by key pop(key)
car["extras"] = car.pop("options")
# 'options'
# OR to change a key name: you can pop an unwanted key and
# save the popped item to a new key
# change options to extras using pop

pp.pprint(car)
# Out:
# {'color': 'red',
#  'doors': 2,
#  'extras': ['sun roof',
#             'mag wheels',
#             'leather seats',
#             'spoiler',
#             'frame decals',
#             'CD player'],
#  'for sale': True,
#  'make': 'Ford',
#  'model': 'Mustang GT',
#  'odometer': 57890,
#  'owner': {'address': {'city': 'Rego Park', 'state': 'New York'},
#            'first_name': 'Brian',
#            'last_name': 'McClain',
#            'zip_code': 11374},
#  'year': 2003}

# %%
# CHALLENGE A: change key name 'for sale' to 'available'
# flip the value of the boolean without explictly setting it
# in other words, you do not have to know the current value
# just make it the opposite of whatever it is now
car["available"] = not car.pop("for sale")
pp.pprint(car)
# Out:
# {'available': False,
#  'color': 'red',
#  'doors': 2,
#  'extras': ['sun roof',
#             'mag wheels',
#             'leather seats',
#             'spoiler',
#             'frame decals',
#             'CD player'],
#  'make': 'Ford',
#  'model': 'Mustang GT',
#  'odometer': 57890,
#  'owner': {'address': {'city': 'Rego Park', 'state': 'New York'},
#            'first_name': 'Brian',
#            'last_name': 'McClain',
#            'zip_code': 11374},
#  'year': 2003}

# %% [markdown]
# accessing items from a property list

# %%
# CHALLENGES
# 9. print just the first item from the extras list


# 10. print the owner of the car's full name: "Brian McClain"

print()

# 11. increase by the odometer reading by 10%
# math shorthand: += adds, -= subtracts, *= multipies, /= divides

# %% [markdown]
# **looping a dictionary**
# - a dictionary stores multiple items, so it makes sense that it is iterable (loopable)
# - you can loop by key or value, or both
# - usually you loop by key

# %%
# 14. loop the car dictionary and print the keys
# 15. print the value by passing k, representing the current key, to the dicitionary
for key in car.keys():
  print(key)

# 16. loop the dictionary by values
print('\nloop the values directly:')
for val in car.values():
  print(val)

print('\nOR loop the keys and loop up the values:')
for key in car:
  print(key, ":", car[key])

print('\nitems:\n')
# 17. loop the dictionary by item, therefore having access to BOTH keys and values:
for key, val in car.items():
  print('key:', key, 'val:', val)
# Out:
# make
# model
# year
# doors
# color
# owner
# odometer
# extras
# available
#
# loop the values directly:
# Ford
# Mustang GT
# 2003
# 2
# red
# {'first_name': 'Brian', 'last_name': 'McClain', 'zip_code': 11374, 'address': {'city': 'Rego Park', 'state': 'New York'}}
# 57890
# ['sun roof', 'mag wheels', 'leather seats', 'spoiler', 'frame decals', 'CD player']
# False
#
# OR loop the keys and loop up the values:
# make : Ford
# model : Mustang GT
# year : 2003
# doors : 2
# color : red
# owner : {'first_name': 'Brian', 'last_name': 'McClain', 'zip_code': 11374, 'address': {'city': 'Rego Park', 'state': 'New York'}}
# odometer : 57890
# extras : ['sun roof', 'mag wheels', 'leather seats', 'spoiler', 'frame decals', 'CD player']
# available : False
#
# items:
#
# key: make val: Ford
# key: model val: Mustang GT
# key: year val: 2003
# key: doors val: 2
# key: color val: red
# ...

# %% [markdown]
# - **list_from_keys = list(dict.keys())**: makes a list of all keys of dictionary
# - **list_from_keys = list(dict.valuess())**: makes a list of all values of dictionary
# - a list can be made from the keys of a dictionary
# - a list can be made from the values of a dictionary

# %%
# 18. make a list of the car keys
keys_list = list(car.keys())
print(keys_list)
# ['make', 'model', 'year', 'color', 'options', 'owner', 'doors', 'odometer', 'for_sale']
# Out:
# ['make', 'model', 'year', 'doors', 'color', 'owner', 'odometer', 'extras', 'available']

# %%
# 19. make a list of the car values:
vals_list = list(car.values())
pp.pprint(vals_list)
# Out:
# ['Ford',
#  'Mustang GT',
#  2003,
#  2,
#  'red',
#  {'address': {'city': 'Rego Park', 'state': 'New York'},
#   'first_name': 'Brian',
#   'last_name': 'McClain',
#   'zip_code': 11374},
#  57890,
#  ['sun roof',
#   'mag wheels',
#   'leather seats',
#   'spoiler',
#   'frame decals',
#   'CD player'],
#  False]

# %%
pp.pprint(vals_list[5]["address"]["state"])
# Out:
# 'New York'

# %% [markdown]
# combining two dictionaries into one
# **dict1.update(dict2)** merges the two dictionaries into dict1

# %%
# combine two dictionaries into one

# 20. Make another dictionary containing additional info about the car:
more_car_data = {
  "vin": "4Y1-SL658-4-8-Z-41-1439",
  "car fax": True,
  "transmission": "manual",
  "mpg": {"city": 14, "hwy": 23},
  "engine": {"cyl": 8, "hp": 260},
  "top speed": 151
}
# "4Y1-SL658-4-8-Z-41-1439",


# 21. add the new dictionary to car
car.update(more_car_data)

# %%
pp.pprint(car)
# Out:
# {'available': False,
#  'car fax': True,
#  'color': 'red',
#  'doors': 2,
#  'engine': {'cyl': 8, 'hp': 260},
#  'extras': ['sun roof',
#             'mag wheels',
#             'leather seats',
#             'spoiler',
#             'frame decals',
#             'CD player'],
#  'make': 'Ford',
#  'model': 'Mustang GT',
#  'mpg': {'city': 14, 'hwy': 23},
#  'odometer': 57890,
#  'owner': {'address': {'city': 'Rego Park', 'state': 'New York'},
#            'first_name': 'Brian',
#            'last_name': 'McClain',
#            'zip_code': 11374},
#  'top speed': 151,
#  'transmission': 'manual',
#  'vin': '4Y1-SL658-4-8-Z-41-1439',
#  'year': 2003}

# %% [markdown]
# **looping lists of dictionaries**
# - a list of dictionaries is essentially a data structure akin to a spread sheet
# - each dictionary list item is a "row"
# - each key is a "column"

# %%
# Given this employees list of dictinaries, one dictionary per employee:
employees = [
  {"fname": "Amy", "lname": "Ames", "salary": 130000, "dept": "IT"},
  {"fname": "Bob", "lname": "Biggs", "salary": 93000, "dept": "Sales"},
  {"fname": "Cal", "lname": "Combs", "salary": 105000, "dept": "IT"},
  {"fname": "Dan", "lname": "Dunn", "salary": 78000, "dept": "Marketing"},
  {"fname": "Edna", "lname": "Evans", "salary": 89000, "dept": "Sales"},
]

# 22. using a for loop, iterate employees list
#     print summaries of each employee as formatted string:
# Expected output:
# Amy Ames works in the IT department".
# Bob Biggs works in the Sales department".
for emp in employees:
  print(f'{emp["fname"]} {emp["lname"]} works in the {emp["dept"]} department.')
  print(f'Annual Bonus: ${int(emp["salary"]*0.1)}\n')

# BONUS CHALLENGE: Announce that everyone gets a BONUS equal to 10% of their salary:
# Amy Ames works in the IT department. Annual Bonus: 13000
# Bob Biggs works in the Sales department. Annual Bonus: 9300
# Out:
# Amy Ames works in the IT department.
# Annual Bonus: $13000
#
# Bob Biggs works in the Sales department.
# Annual Bonus: $9300
#
# Cal Combs works in the IT department.
# Annual Bonus: $10500
#
# Dan Dunn works in the Marketing department.
# Annual Bonus: $7800
#
# Edna Evans works in the Sales department.
# Annual Bonus: $8900

# %%
# given this list of 10 similar car dictionaries:
cars = [
    {'VIN': '4Y1-SL658-4-8-Z-41-1439',
     'available': False,
     'car fax': True,
     'color': 'red',
     'condition': 'excellent',
     'doors': 2,
     'engine': {'cyl': 8, 'hp': 260, 'ltr': 5.0},
     'extras': ['sun roof',
                'mag wheels',
                'leather seats',
                'spoiler',
                'frame decals'],
     'make': 'Ford',
     'model': 'Mustang GT',
     'mpg': {'city': 14, 'hwy': 23},
     'odometer': 71639.21160000002,
     'owner': {'first name': 'Brian',
               'last name': 'McClain',
               'original owner': False,
               'zip code': 10011},
     'top speed': 151,
     'transmission': 'manual',
     'year': 2003},

    {'VIN': '3FA6P0H74HR245678',
     'available': True,
     'car fax': True,
     'color': 'blue',
     'condition': 'good',
     'doors': 4,
     'engine': {'cyl': 4, 'hp': 175, 'ltr': 2.5},
     'extras': ['backup camera', 'Bluetooth', 'cruise control'],
     'make': 'Ford',
     'model': 'Fusion',
     'mpg': {'city': 21, 'hwy': 32},
     'odometer': 45821.35,
     'owner': {'first name': 'Emily',
               'last name': 'Jones',
               'original owner': True,
               'zip code': 94110},
     'top speed': 130,
     'transmission': 'automatic',
     'year': 2017},

    {'VIN': '5J8TB3H5XFL012345',
     'available': True,
     'car fax': False,
     'color': 'white',
     'condition': 'fair',
     'doors': 4,
     'engine': {'cyl': 6, 'hp': 280, 'ltr': 3.5},
     'extras': ['navigation system', 'heated seats'],
     'make': 'Acura',
     'model': 'RDX',
     'mpg': {'city': 20, 'hwy': 28},
     'odometer': 95342.11,
     'owner': {'first name': 'John',
               'last name': 'Smith',
               'original owner': False,
               'zip code': 60614},
     'top speed': 135,
     'transmission': 'automatic',
     'year': 2015},

    {'VIN': '1C4RJFAG4FC123456',
     'available': False,
     'car fax': True,
     'color': 'black',
     'condition': 'excellent',
     'doors': 4,
     'engine': {'cyl': 6, 'hp': 295, 'ltr': 3.6},
     'extras': ['4WD', 'sun roof', 'leather seats'],
     'make': 'Jeep',
     'model': 'Grand Cherokee',
     'mpg': {'city': 18, 'hwy': 25},
     'odometer': 60213.75,
     'owner': {'first name': 'Sarah',
               'last name': 'Brown',
               'original owner': True,
               'zip code': 75201},
     'top speed': 119,
     'transmission': 'automatic',
     'year': 2016},

    {'VIN': '19XFC2F59HE234567',
     'available': True,
     'car fax': True,
     'color': 'silver',
     'condition': 'excellent',
     'doors': 4,
     'engine': {'cyl': 4, 'hp': 158, 'ltr': 2.0},
     'extras': ['Bluetooth', 'backup camera', 'cruise control'],
     'make': 'Honda',
     'model': 'Civic',
     'mpg': {'city': 30, 'hwy': 38},
     'odometer': 34219.55,
     'owner': {'first name': 'Michael',
               'last name': 'Davis',
               'original owner': False,
               'zip code': 30303},
     'top speed': 125,
     'transmission': 'manual',
     'year': 2017},

    {'VIN': '2T1BURHE4JC345678',
     'available': True,
     'car fax': False,
     'color': 'red',
     'condition': 'good',
     'doors': 4,
     'engine': {'cyl': 4, 'hp': 132, 'ltr': 1.8},
     'extras': ['Bluetooth', 'backup camera'],
     'make': 'Toyota',
     'model': 'Corolla',
     'mpg': {'city': 28, 'hwy': 36},
     'odometer': 41258.77,
     'owner': {'first name': 'Ashley',
               'last name': 'Wilson',
               'original owner': True,
               'zip code': 98101},
     'top speed': 115,
     'transmission': 'automatic',
     'year': 2018},

    {'VIN': '3VW2B7AJ7HM456789',
     'available': False,
     'car fax': True,
     'color': 'green',
     'condition': 'fair',
     'doors': 4,
     'engine': {'cyl': 4, 'hp': 170, 'ltr': 1.8},
     'extras': ['heated seats', 'Bluetooth'],
     'make': 'Volkswagen',
     'model': 'Jetta',
     'mpg': {'city': 24, 'hwy': 33},
     'odometer': 67321,
     'owner': {'first name': 'David',
               'last name': 'Martinez',
               'original owner': False,
               'zip code': 80202},
     'top speed': 126,
     'transmission': 'manual',
     'year': 2017},

    {'VIN': '1N4AL3AP7JC678901',
     'available': True,
     'car fax': False,
     'color': 'black',
     'condition': 'excellent',
     'doors': 4,
     'engine': {'cyl': 4, 'hp': 182, 'ltr': 2.5},
     'extras': ['backup camera', 'Bluetooth', 'sun roof'],
     'make': 'Nissan',
     'model': 'Altima',
     'mpg': {'city': 27, 'hwy': 38},
     'odometer': 52873.98,
     'owner': {'first name': 'Jessica',
               'last name': 'Garcia',
               'original owner': True,
               'zip code': 94105},
     'top speed': 130,
     'transmission': 'automatic',
     'year': 2018},

    {'VIN': 'WBA8E9C56GK123456',
     'available': True,
     'car fax': True,
     'color': 'white',
     'condition': 'good',
     'doors': 4,
     'engine': {'cyl': 4, 'hp': 248, 'ltr': 2.0},
     'extras': ['navigation system', 'heated seats', 'sun roof'],
     'make': 'BMW',
     'model': '328i',
     'mpg': {'city': 23, 'hwy': 34},
     'odometer': 37821.67,
     'owner': {'first name': 'Chris',
               'last name': 'Robinson',
               'original owner': False,
               'zip code': 60610},
     'top speed': 155,
     'transmission': 'automatic',
     'year': 2016},

    {'VIN': '1FTFW1EF1HFB12345',
     'available': False,
     'car fax': True,
     'color': 'blue',
     'condition': 'excellent',
     'doors': 4,
     'engine': {'cyl': 8, 'hp': 385, 'ltr': 5.0},
     'extras': ['4WD', 'backup camera', 'Bluetooth'],
     'make': 'Ford',
     'model': 'F-150',
     'mpg': {'city': 15, 'hwy': 21},
     'odometer': 29872.99,
     'owner': {'first name': 'Mark',
               'last name': 'Hernandez',
               'original owner': True,
               'zip code': 33101},
     'top speed': 105,
     'transmission': 'automatic',
     'year': 2017}
]

# %%
# CHALLENGE A
# loop the list of car dictionaries and save image file names for each to new list
# callec car_imgs the year make and model of each as image file name:
# expected output:
car_imgs = [] # ["2003 Ford Mustang GT.jpg", "2017 Ford Fusion.jpg", etc..]

# %%
# CHALLENGE B
# Loop the ChatGPT-provided cars list of dictionaries
# Each time through the list, print FOR SALE listings for each car:

# EXAMPLE:
# For Sale: 2003 Ford Mustang GT -
# Emgine: 8 cyl, manual transmission, excellent condition,
# 71,639 miles, red, many extras: leather seats, sunroof, more


# looping through list of car dict
# "For Sale:"
# " Now Only "
# "\n Powerful "
# " condition, and comes in \n"
